# %% [markdown]
# Practical implementation of Simple RNN

# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774955323.525990   31809 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1774955324.309008   31809 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774955334.088103   31809 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
# define the vocabulary size 
voc_size = 10000

# %%
#One hot representation
one_hot_repre = [one_hot(words, voc_size)for words in sent]
one_hot_repre
# Out:
# [[7383, 209, 6212, 4384],
#  [7383, 209, 6212, 3609],
#  [7383, 1512, 6212, 2832],
#  [227, 6378, 7472, 3392, 3791],
#  [227, 6378, 7472, 3392, 7572],
#  [1145, 7383, 3369, 6212, 3001],
#  [6422, 343, 5841, 3392]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
sent_length = 8

# %%
import numpy as np

# %%
# here we use padding sequences in order to make all sentences of same size.
embedded_docs = pad_sequences(one_hot_repre, padding='pre', maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 7383  209 6212 4384]
#  [   0    0    0    0 7383  209 6212 3609]
#  [   0    0    0    0 7383 1512 6212 2832]
#  [   0    0    0  227 6378 7472 3392 3791]
#  [   0    0    0  227 6378 7472 3392 7572]
#  [   0    0    0 1145 7383 3369 6212 3001]
#  [   0    0    0    0 6422  343 5841 3392]]

# %%
## feature representation with dimension size of 10
dim = 10

# %%
from tensorflow.keras.layers import Input

# %%
model = Sequential()
# Move the shape definition here
model.add(Input(shape=(sent_length,))) 
# Remove input_length from here
model.add(Embedding(voc_size, dim)) 
model.compile(optimizer='adam', loss='mse')
# Out:
# E0000 00:00:1774955394.402305   31809 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# array([[[ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.03927575,  0.01968739,  0.00529951, -0.00390105,
#           0.0034987 ,  0.01475273,  0.02095418,  0.02901237,
#          -0.00681485,  0.03875614],
#         [ 0.0163525 ,  0.01549398,  0.01536949,  0.03402353,
#          -0.02455372,  0.00775527, -0.04832511, -0.04650197,
#           0.04887496, -0.01984086],
#         [-0.01386067,  0.03999784, -0.04258511,  0.02010839,
#           0.04185138,  0.01840628, -0.04191605,  0.02878574,
#           0.04546212,  0.04202851],
#         [-0.04115417,  0.02643855,  0.02757676,  0.03462366,
#           0.03008784, -0.0198236 ,  0.00426822, -0.00560648,
#           0.01170275,  0.01944107]],
#
#        [[ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.03927575,  0.01968739,  0.00529951, -0.00390105,
#           0.0034987 ,  0.01475273,  0.02095418,  0.02901237,
#          -0.00681485,  0.03875614],
#         [ 0.0163525 ,  0.01549398,  0.01536949,  0.03402353,
#          -0.02455372,  0.00775527, -0.04832511, -0.04650197,
#           0.04887496, -0.01984086],
#         [-0.01386067,  0.03999784, -0.04258511,  0.02010839,
#           0.04185138,  0.01840628, -0.04191605,  0.02878574,
#           0.04546212,  0.04202851],
#         [-0.04229837,  0.02878013,  0.03036075,  0.04034886,
#           0.03583095,  0.00622267,  0.03323804, -0.00498237,
#          -0.04856175, -0.02434224]],
#
#        [[ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.03927575,  0.01968739,  0.00529951, -0.00390105,
#           0.0034987 ,  0.01475273,  0.02095418,  0.02901237,
#          -0.00681485,  0.03875614],
#         [-0.03264841,  0.00666053, -0.00914371,  0.00147464,
#          -0.01019101,  0.02022925,  0.02792633, -0.01132164,
#          -0.03109884,  0.01028719],
#         [-0.01386067,  0.03999784, -0.04258511,  0.02010839,
#           0.04185138,  0.01840628, -0.04191605,  0.02878574,
#           0.04546212,  0.04202851],
#         [-0.04495407, -0.03273223, -0.00288775,  0.02136524,
#          -0.02130072, -0.01474245, -0.00305363, -0.00175612,
#           0.03158066,  0.021839  ]],
#
#        [[ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.0118845 ,  0.03088159,  0.04033942, -0.01494818,
#          -0.02748072,  0.01903487, -0.02342927,  0.04825345,
#           0.02510283,  0.02524329],
#         [ 0.03514937, -0.02573007, -0.0145362 , -0.00665627,
#           0.0470423 ,  0.03141472,  0.02614171, -0.01113275,
#           0.01631129,  0.03686481],
#         [ 0.0433959 ,  0.03737004,  0.03675188,  0.02909419,
#          -0.01000621,  0.02041782, -0.04491639, -0.04392977,
#           0.01329173,  0.04957303],
#         [ 0.00167076,  0.00224242,  0.0299641 ,  0.0008629 ,
#          -0.02140999,  0.04201373, -0.01746074,  0.00925634,
#          -0.04676395,  0.00996388],
#         [-0.00375209, -0.03065966,  0.01477328, -0.03851895,
#          -0.03032966, -0.00664247, -0.00227223,  0.04449132,
#           0.00654041,  0.00492703]],
#
#        [[ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.0118845 ,  0.03088159,  0.04033942, -0.01494818,
#          -0.02748072,  0.01903487, -0.02342927,  0.04825345,
#           0.02510283,  0.02524329],
#         [ 0.03514937, -0.02573007, -0.0145362 , -0.00665627,
#           0.0470423 ,  0.03141472,  0.02614171, -0.01113275,
#           0.01631129,  0.03686481],
#         [ 0.0433959 ,  0.03737004,  0.03675188,  0.02909419,
#          -0.01000621,  0.02041782, -0.04491639, -0.04392977,
#           0.01329173,  0.04957303],
#         [ 0.00167076,  0.00224242,  0.0299641 ,  0.0008629 ,
#          -0.02140999,  0.04201373, -0.01746074,  0.00925634,
#          -0.04676395,  0.00996388],
#         [-0.02451172, -0.01070227,  0.04684949,  0.02408839,
#           0.03224394,  0.03868199, -0.01689876, -0.02378403,
#          -0.03381797,  0.04556168]],
#
#        [[ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.04276753,  0.04061573, -0.0405488 , -0.04580264,
#           0.04088601,  0.01232536, -0.01645128,  0.00391186,
#          -0.00708709,  0.00380479],
#         [ 0.03927575,  0.01968739,  0.00529951, -0.00390105,
#           0.0034987 ,  0.01475273,  0.02095418,  0.02901237,
#          -0.00681485,  0.03875614],
#         [-0.00476372, -0.04269239,  0.03269342,  0.01135159,
#           0.01824358, -0.04979602, -0.01881409,  0.04516831,
#          -0.0461225 ,  0.02663862],
#         [-0.01386067,  0.03999784, -0.04258511,  0.02010839,
#           0.04185138,  0.01840628, -0.04191605,  0.02878574,
#           0.04546212,  0.04202851],
#         [-0.02443703,  0.00387741,  0.02947456,  0.03856466,
#           0.04869237,  0.03278902,  0.01580794, -0.01535507,
#           0.02827486,  0.02743519]],
#
#        [[ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.01908961,  0.01538949, -0.03528502,  0.03267405,
#           0.01691308,  0.01262477, -0.01833941, -0.0413442 ,
#          -0.02286621,  0.04917804],
#         [ 0.03061518,  0.04589191,  0.00409605,  0.01425289,
#           0.0493936 ,  0.03613215,  0.04817071, -0.03462525,
#          -0.02840787,  0.04213412],
#         [ 0.00479465, -0.04534335,  0.01217846, -0.00610017,
#           0.00433228,  0.04398736, -0.04550511, -0.0412441 ,
#          -0.00832915, -0.03736188],
#         [ 0.03810599,  0.0298607 , -0.02983303, -0.04395739,
#          -0.0361434 , -0.03080049, -0.01089012, -0.03873774,
#           0.04714639,  0.03534255],
#         [ 0.00167076,  0.00224242,  0.0299641 ,  0.0008629 ,
#          -0.02140999,  0.04201373, -0.01746074,  0.00925634,
#          -0.04676395,  0.00996388]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 7383,  209, 6212, 4384], dtype=int32)
